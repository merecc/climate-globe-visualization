# %% [markdown]
# # Temperature Data Processing for 3D Globe Visualization
#
# This notebook contains the code necessary to process temperature anomaly data and generate images for each year. These images are then used to overlay on a 3D globe visualization in a web application. The process involves two main steps:
#
# 1. **Interpolation of Sparse Data:** Converts sparse latitude-longitude temperature points into a consistent grid format that can be easily visualized.
# 2. **Image Generation:** Creates colored temperature anomaly images from the interpolated data, which are tailored to highlight various temperature ranges with specific colors.

# %%
import xarray as xr
import numpy as np
import cartopy.crs as ccrs
import xarray as xr
import matplotlib.pyplot as plt
from scipy.interpolate import griddata
from PIL import Image

# %% [markdown]
# interpolates temperature data to a regular grid

# %%
file_path = '/Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/gistemp1200_GHCNv4_ERSSTv5.nc' 
output_dir = '/Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources'

# %%
def generate_anomaly_maps(file_path, start_year, end_year, output_dir):
    # Load the dataset
    data = xr.open_dataset(file_path)

    for year in range(start_year, end_year + 1):
        print(f"Processing year: {year}")
        try:
            # Select data for the specified year
            yearly_data = data.sel(time=str(year))
            mean_anomaly = yearly_data['tempanomaly'].mean(dim='time')

            # Handle null values by masking them
            mean_anomaly = mean_anomaly.where(~mean_anomaly.isnull())

            # Create a figure with a geographic projection
            plt.figure(figsize=(10, 5))
            ax = plt.axes(projection=ccrs.PlateCarree())  # Set the geographic projection
            
            # Plotting the data without a color bar
            img = mean_anomaly.plot(ax=ax, transform=ccrs.PlateCarree(),
                                    cmap='coolwarm', add_colorbar=False)

            # Add coastlines for geographical reference
            ax.coastlines('110m', linewidth=0.8)
            ax.set_global()  # Set the map to global scale

            plt.axis('off') 
            # Save the figure
            output_file = f"{output_dir}/temp_anomaly_{year}.png"
            plt.savefig(output_file, dpi=300, bbox_inches='tight', pad_inches=0, transparent=True)
            plt.close()
            print(f"Saved: {output_file}")
        except Exception as e:
            print(f"Failed to process year {year}: {e}")

generate_anomaly_maps(file_path, 1973, 2024, output_dir)
# Out:
# Processing year: 1973
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_1973.png
# Processing year: 1974
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_1974.png
# Processing year: 1975
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_1975.png
# Processing year: 1976
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_1976.png
# Processing year: 1977
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_1977.png
# Processing year: 1978
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_1978.png
# Processing year: 1979
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_1979.png
# Processing year: 1980
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_1980.png
# Processing year: 1981
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_1981.png
# Processing year: 1982
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_1982.png
# Processing year: 1983
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_1983.png
# Processing year: 1984
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_1984.png
# Processing year: 1985
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_1985.png
# Processing year: 1986
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_1986.png
# Processing year: 1987
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_1987.png
# Processing year: 1988
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_1988.png
# Processing year: 1989
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_1989.png
# Processing year: 1990
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_1990.png
# Processing year: 1991
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_1991.png
# Processing year: 1992
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_1992.png
# Processing year: 1993
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_1993.png
# Processing year: 1994
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_1994.png
# Processing year: 1995
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_1995.png
# Processing year: 1996
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_1996.png
# Processing year: 1997
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_1997.png
# Processing year: 1998
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_1998.png
# Processing year: 1999
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_1999.png
# Processing year: 2000
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_2000.png
# Processing year: 2001
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_2001.png
# Processing year: 2002
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_2002.png
# Processing year: 2003
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_2003.png
# Processing year: 2004
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_2004.png
# Processing year: 2005
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_2005.png
# Processing year: 2006
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_2006.png
# Processing year: 2007
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_2007.png
# Processing year: 2008
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_2008.png
# Processing year: 2009
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_2009.png
# Processing year: 2010
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_2010.png
# Processing year: 2011
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_2011.png
# Processing year: 2012
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_2012.png
# Processing year: 2013
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_2013.png
# Processing year: 2014
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_2014.png
# Processing year: 2015
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_2015.png
# Processing year: 2016
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_2016.png
# Processing year: 2017
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_2017.png
# Processing year: 2018
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_2018.png
# Processing year: 2019
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_2019.png
# Processing year: 2020
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_2020.png
# Processing year: 2021
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_2021.png
# Processing year: 2022
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_2022.png
# Processing year: 2023
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_2023.png
# Processing year: 2024
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly_2024.png

# %%
def generate_anomaly_maps(file_path, start_year, end_year, output_dir):
    # Load the dataset
    data = xr.open_dataset(file_path)

    for year in range(start_year, end_year + 1):
        yearly_data = data.sel(time=str(year))
        mean_anomaly = yearly_data['tempanomaly'].mean(dim='time')
        
      
        mean_anomaly = mean_anomaly.where(~np.isnan(mean_anomaly), other=np.nan)
   
        plt.figure(figsize=(10, 5))
        ax = plt.axes(projection=ccrs.PlateCarree()) 
        
        # Plotting the data
        mean_anomaly.plot(ax=ax, transform=ccrs.PlateCarree(),
                               cmap='coolwarm', cbar_kwargs={'shrink': 0.5},
                               add_colorbar=True)
        
  
        ax.coastlines()
        ax.set_global()  
        
      
        output_file = f"{output_dir}/temp_anomaly__w_scale{year}.png"
        plt.savefig(output_file, dpi=300, bbox_inches='tight', pad_inches=0)
        plt.close()
        print(f"Saved: {output_file}")

generate_anomaly_maps(file_path, 1973, 2024, output_dir)
# Out:
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale1973.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale1974.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale1975.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale1976.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale1977.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale1978.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale1979.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale1980.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale1981.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale1982.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale1983.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale1984.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale1985.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale1986.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale1987.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale1988.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale1989.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale1990.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale1991.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale1992.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale1993.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale1994.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale1995.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale1996.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale1997.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale1998.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale1999.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale2000.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale2001.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale2002.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale2003.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale2004.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale2005.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale2006.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale2007.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale2008.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale2009.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale2010.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale2011.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale2012.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale2013.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale2014.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale2015.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale2016.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale2017.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale2018.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale2019.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale2020.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale2021.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale2022.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale2023.png
# Saved: /Users/merecanova/Desktop/INST_630/Final_project/Finding_data_sources/temp_anomaly__w_scale2024.png
